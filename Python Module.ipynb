# %% [markdown]
# # Modular Programming

# %% [markdown]
# **Modules** คือ *Software* ชิ้นส่วนย่อนๆ ที่ถูกเขียนออกมาแยกจากกัน โดยแต่ละ Modules มีการทำงานที่เฉพาะเจาะจง และสามารถให้ Modules หรือ โปรแกรมอื่นมารวมใช้งานหรือเรียกใช้งานร่วมกันได้
#
# - การแก้ไขจะไม่มีผลกระทบต่อโปรแกรมในภาพรวมหรือ Modules อื่นๆ

# %% [markdown]
# ![%E0%B8%AA%E0%B8%81%E0%B8%A3%E0%B8%B5%E0%B8%99%E0%B8%8A%E0%B9%87%E0%B8%AD%E0%B8%95_25651024_120435.png](attachment:%E0%B8%AA%E0%B8%81%E0%B8%A3%E0%B8%B5%E0%B8%99%E0%B8%8A%E0%B9%87%E0%B8%AD%E0%B8%95_25651024_120435.png)

# %% [markdown]
# ![%E0%B8%AA%E0%B8%81%E0%B8%A3%E0%B8%B5%E0%B8%99%E0%B8%8A%E0%B9%87%E0%B8%AD%E0%B8%95_25651024_120727.png](attachment:%E0%B8%AA%E0%B8%81%E0%B8%A3%E0%B8%B5%E0%B8%99%E0%B8%8A%E0%B9%87%E0%B8%AD%E0%B8%95_25651024_120727.png)

# %% [markdown]
# ![%E0%B8%AA%E0%B8%81%E0%B8%A3%E0%B8%B5%E0%B8%99%E0%B8%8A%E0%B9%87%E0%B8%AD%E0%B8%95_25651024_120907.png](attachment:%E0%B8%AA%E0%B8%81%E0%B8%A3%E0%B8%B5%E0%B8%99%E0%B8%8A%E0%B9%87%E0%B8%AD%E0%B8%95_25651024_120907.png)

# %% [markdown]
# ## 1. How to Use Python Module
# --------------------------------------------------------

# %%
import random

random.randint(1,10)
# Out:
# 2

# %% [markdown]
#  ## โครงสร้างของ Modules ใน Python
#  -----------------------------------------------------------------------
#  ![%E0%B8%AA%E0%B8%81%E0%B8%A3%E0%B8%B5%E0%B8%99%E0%B8%8A%E0%B9%87%E0%B8%AD%E0%B8%95_25651024_121957.png](attachment:%E0%B8%AA%E0%B8%81%E0%B8%A3%E0%B8%B5%E0%B8%99%E0%B8%8A%E0%B9%87%E0%B8%AD%E0%B8%95_25651024_121957.png)

# %% [markdown]
# # How to Use Modules
# ------------------------------------------------------------------------
# ![%E0%B8%AA%E0%B8%81%E0%B8%A3%E0%B8%B5%E0%B8%99%E0%B8%8A%E0%B9%87%E0%B8%AD%E0%B8%95_25651024_122316.png](attachment:%E0%B8%AA%E0%B8%81%E0%B8%A3%E0%B8%B5%E0%B8%99%E0%B8%8A%E0%B9%87%E0%B8%AD%E0%B8%95_25651024_122316.png)

# %% [markdown]
# ![%E0%B8%AA%E0%B8%81%E0%B8%A3%E0%B8%B5%E0%B8%99%E0%B8%8A%E0%B9%87%E0%B8%AD%E0%B8%95_25651024_122407.png](attachment:%E0%B8%AA%E0%B8%81%E0%B8%A3%E0%B8%B5%E0%B8%99%E0%B8%8A%E0%B9%87%E0%B8%AD%E0%B8%95_25651024_122407.png)

# %% [markdown]
# - Check **Python module search path** of your environment

# %%
import sys

sys.path
# Out:
# ['C:\\Users\\nutch\\Nutchapon',
#  'C:\\Users\\nutch\\miniconda3\\python39.zip',
#  'C:\\Users\\nutch\\miniconda3\\DLLs',
#  'C:\\Users\\nutch\\miniconda3\\lib',
#  'C:\\Users\\nutch\\miniconda3',
#  '',
#  'C:\\Users\\nutch\\miniconda3\\lib\\site-packages',
#  'C:\\Users\\nutch\\miniconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\nutch\\miniconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\nutch\\miniconda3\\lib\\site-packages\\Pythonwin']

# %% [markdown]
# #### 2.1 Use module in current directory

# %%
import dice

dice.roll_dice(2)
# Out:
# Use from current folder...
# [4, 6]
