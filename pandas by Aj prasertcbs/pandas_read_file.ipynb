# %% [markdown]
# # การอ่านไฟล์ที่มีข้อมูล (date/time data)

# %% [markdown]
# ## การอ่านข้อมูล text file ที่มีวันเวลา

# %%
import pandas as pd

# %%
df=pd.read_table('https://github.com/prasertcbs/tutorial/raw/master/datetime.tsv')
df
# Out:
#   date_stamp date_stamp2 date_stamp3    iso_date         fmt1          fmt2  \
# 0   28/11/16    28-11-16    11/28/16  2016-11-28  28-Nov-2016  Nov 28, 2016
# 1     7/8/16      7-8-16      8/7/16  2016-08-07  07-Aug-2016   Aug 7, 2016
# 2    10/6/16     10-6-16     6/10/16  2016-06-10  10-Jun-2016  Jun 10, 2016
# 3    26/3/16     26-3-16     3/26/16  2016-03-26  26-Mar-2016  Mar 26, 2016
# 4    26/7/17     26-7-17     7/26/17  2017-07-26  26-Jul-2017  Jul 26, 2017
# 5    20/5/15     20-5-15     5/20/15  2015-05-20  20-May-2015  May 20, 2015
# 6    10/8/16     10-8-16     8/10/16  2016-08-10  10-Aug-2016  Aug 10, 2016
# 7    18/2/15     18-2-15     2/18/15  2015-02-18  18-Feb-2015  Feb 18, 2015
# 8     6/2/16      6-2-16      2/6/16  2016-02-06  06-Feb-2016   Feb 6, 2016
# 9     4/8/15      4-8-15      8/4/15  2015-08-04  04-Aug-2015   Aug 4, 2015
#
#         ym       ymd         ymdhm        tm     y   m   d gender   menu  \
# ...

# %%
df.dtypes # check data-types
# Out:
# date_stamp     object
# date_stamp2    object
# date_stamp3    object
# iso_date       object
# fmt1           object
# fmt2           object
# ym             object
# ymd             int64
# ymdhm           int64
# tm             object
# y               int64
# m               int64
# d               int64
# gender         object
# menu           object
# price           int64
# member           bool
# dtype: object

# %%
df['date_stamp'] = pd.to_datetime(df.date_stamp)

# %%
df.head()
# Out:
#   date_stamp date_stamp2 date_stamp3    iso_date         fmt1          fmt2  \
# 0 2016-11-28    28-11-16    11/28/16  2016-11-28  28-Nov-2016  Nov 28, 2016
# 1 2016-07-08      7-8-16      8/7/16  2016-08-07  07-Aug-2016   Aug 7, 2016
# 2 2016-10-06     10-6-16     6/10/16  2016-06-10  10-Jun-2016  Jun 10, 2016
# 3 2016-03-26     26-3-16     3/26/16  2016-03-26  26-Mar-2016  Mar 26, 2016
# 4 2017-07-26     26-7-17     7/26/17  2017-07-26  26-Jul-2017  Jul 26, 2017
#
#         ym       ymd         ymdhm        tm     y   m   d gender   menu  \
# 0  2016-11  20161128  201611282313   6:28 PM  2016  11  28      F  water
# 1  2016-08  20160807  201608071555   9:51 AM  2016   8   7      M  water
# 2  2016-06  20160610  201606100707  11:52 AM  2016   6  10      M  water
# 3  2016-03  20160326  201603261013   5:54 AM  2016   3  26      F  water
# 4  2017-07  20170726  201707260705   1:40 AM  2017   7  26      F    tea
#
#    price  member
# 0     38    True
# 1     48    True
# ...

# %%
df.dtypes
# Out:
# date_stamp     datetime64[ns]
# date_stamp2            object
# date_stamp3            object
# iso_date               object
# fmt1                   object
# fmt2                   object
# ym                     object
# ymd                     int64
# ymdhm                   int64
# tm                     object
# y                       int64
# m                       int64
# d                       int64
# gender                 object
# menu                   object
# price                   int64
# member                   bool
# dtype: object

# %%
df['ymd2'] = pd.to_datetime(df.ymd)

# %%
df.head()
# Out:
#   date_stamp date_stamp2 date_stamp3    iso_date         fmt1          fmt2  \
# 0 2016-11-28    28-11-16    11/28/16  2016-11-28  28-Nov-2016  Nov 28, 2016
# 1 2016-07-08      7-8-16      8/7/16  2016-08-07  07-Aug-2016   Aug 7, 2016
# 2 2016-10-06     10-6-16     6/10/16  2016-06-10  10-Jun-2016  Jun 10, 2016
# 3 2016-03-26     26-3-16     3/26/16  2016-03-26  26-Mar-2016  Mar 26, 2016
# 4 2017-07-26     26-7-17     7/26/17  2017-07-26  26-Jul-2017  Jul 26, 2017
#
#         ym       ymd         ymdhm        tm     y   m   d gender   menu  \
# 0  2016-11  20161128  201611282313   6:28 PM  2016  11  28      F  water
# 1  2016-08  20160807  201608071555   9:51 AM  2016   8   7      M  water
# 2  2016-06  20160610  201606100707  11:52 AM  2016   6  10      M  water
# 3  2016-03  20160326  201603261013   5:54 AM  2016   3  26      F  water
# 4  2017-07  20170726  201707260705   1:40 AM  2017   7  26      F    tea
#
#    price  member                          ymd2
# ...

# %%
df['ymd3'] = pd.to_datetime(df.ymd, format='%Y%m%d')

# %% [markdown]
# String format time
# Ref: https://strftime.org/

# %%
df.head()
# Out:
#   date_stamp date_stamp2 date_stamp3    iso_date         fmt1          fmt2  \
# 0 2016-11-28    28-11-16    11/28/16  2016-11-28  28-Nov-2016  Nov 28, 2016
# 1 2016-07-08      7-8-16      8/7/16  2016-08-07  07-Aug-2016   Aug 7, 2016
# 2 2016-10-06     10-6-16     6/10/16  2016-06-10  10-Jun-2016  Jun 10, 2016

# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-02-01  174.500000  175.500000  173.500000  175.500000  169.355362
# 2017-02-02  175.000000  177.000000  174.500000  175.500000  169.355362
# 2017-02-03  175.000000  178.500000  175.000000  178.500000  172.250336
# 2017-02-06  178.500000  181.500000  178.500000  180.500000  174.180313
# 2017-02-07  180.500000  181.000000  179.000000  180.000000  173.697815
# 2017-02-08  180.000000  180.000000  178.500000  179.000000  172.732819
# 2017-02-09  179.500000  182.500000  179.500000  181.000000  174.662796
# 2017-02-10  182.000000  182.500000  181.000000  182.500000  176.110275
# 2017-02-13  182.500000  182.500000  182.500000  182.500000  176.110275
# 2017-02-14  182.000000  182.500000  179.000000  179.000000  172.732819
# 2017-02-01   19.000000   19.200001   18.900000   19.200001   18.366062
# 2017-02-02   19.200001   19.200001   18.900000   19.000000   18.174747
# ...

# %%
df = pd.concat(dfs, keys=stocks)
df
# Out:
#                       Open        High         Low       Close   Adj Close  \
#     Date
# bbl 2017-02-01  174.500000  175.500000  173.500000  175.500000  169.355362
#     2017-02-02  175.000000  177.000000  174.500000  175.500000  169.355362
#     2017-02-03  175.000000  178.500000  175.000000  178.500000  172.250336
#     2017-02-06  178.500000  181.500000  178.500000  180.500000  174.180313
#     2017-02-07  180.500000  181.000000  179.000000  180.000000  173.697815
#     2017-02-08  180.000000  180.000000  178.500000  179.000000  172.732819
#     2017-02-09  179.500000  182.500000  179.500000  181.000000  174.662796
#     2017-02-10  182.000000  182.500000  181.000000  182.500000  176.110275
#     2017-02-13  182.500000  182.500000  182.500000  182.500000  176.110275
#     2017-02-14  182.000000  182.500000  179.000000  179.000000  172.732819
# ktb 2017-02-01   19.000000   19.200001   18.900000   19.200001   18.366062
# ...

# %%
df.index
# Out:
# MultiIndex([('bbl', '2017-02-01'),
#             ('bbl', '2017-02-02'),
#             ('bbl', '2017-02-03'),
#             ('bbl', '2017-02-06'),
#             ('bbl', '2017-02-07'),
#             ('bbl', '2017-02-08'),
#             ('bbl', '2017-02-09'),
#             ('bbl', '2017-02-10'),
#             ('bbl', '2017-02-13'),
#             ('bbl', '2017-02-14'),
#             ('ktb', '2017-02-01'),
#             ('ktb', '2017-02-02'),
#             ('ktb', '2017-02-03'),
#             ('ktb', '2017-02-06'),
#             ('ktb', '2017-02-07'),
#             ('ktb', '2017-02-08'),
#             ('ktb', '2017-02-09'),
#             ('ktb', '2017-02-10'),
#             ('ktb', '2017-02-13'),
#             ('ktb', '2017-02-14'),
#             ('scb', '2017-02-01'),
#             ('scb', '2017-02-02'),
#             ('scb', '2017-02-03'),
#             ('scb', '2017-02-06'),
#             ('scb', '2017-02-07'),
#             ('scb', '2017-02-08'),
#             ('scb', '2017-02-09'),
# ...

# %%
df.loc['scb']
# Out:
#              Open   High    Low  Close   Adj Close     Volume
# Date
# 2017-02-01  150.5  153.0  150.5  152.0  146.727814  6969200.0
# 2017-02-02  152.0  153.0  151.0  151.0  145.762512  6529100.0
# 2017-02-03  151.0  153.5  151.0  153.0  147.693130  6597700.0
# 2017-02-06  154.0  155.0  153.5  154.5  149.141098  9901200.0
# 2017-02-07  154.5  155.0  153.5  154.0  148.658447  3802600.0
# 2017-02-08  153.5  154.5  153.0  154.0  148.658447  5747300.0
# 2017-02-09  154.5  156.0  153.5  154.0  148.658447  6157400.0
# 2017-02-10  154.5  155.0  154.0  154.0  148.658447  9620500.0
# 2017-02-13  154.0  154.0  154.0  154.0  148.658447        0.0
# 2017-02-14  155.0  156.0  153.0  154.0  148.658447  9754000.0

# %%
df.loc['scb']['Close']
# Out:
# Date
# 2017-02-01    152.0
# 2017-02-02    151.0
# 2017-02-03    153.0
# 2017-02-06    154.5
# 2017-02-07    154.0
# 2017-02-08    154.0
# 2017-02-09    154.0
# 2017-02-10    154.0
# 2017-02-13    154.0
# 2017-02-14    154.0
# Name: Close, dtype: float64

# %%
df.loc['scb']['Close'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df.to_excel('stocks.xlsx')

# %%
df = pd.concat(dfs, keys=stocks, names=['Symbol','Date'])
df
# Out:
#                          Open        High         Low       Close   Adj Close  \
# Symbol Date
# bbl    2017-02-01  174.500000  175.500000  173.500000  175.500000  169.355362
#        2017-02-02  175.000000  177.000000  174.500000  175.500000  169.355362
#        2017-02-03  175.000000  178.500000  175.000000  178.500000  172.250336
#        2017-02-06  178.500000  181.500000  178.500000  180.500000  174.180313
#        2017-02-07  180.500000  181.000000  179.000000  180.000000  173.697815
#        2017-02-08  180.000000  180.000000  178.500000  179.000000  172.732819
#        2017-02-09  179.500000  182.500000  179.500000  181.000000  174.662796
#        2017-02-10  182.000000  182.500000  181.000000  182.500000  176.110275
#        2017-02-13  182.500000  182.500000  182.500000  182.500000  176.110275
#        2017-02-14  182.000000  182.500000  179.000000  179.000000  172.732819
# ktb    2017-02-01   19.000000   19.200001   18.900000   19.200001   18.366062
# ...
